# %% [markdown]
# <a href="https://colab.research.google.com/github/palepu-bala-siddhartha/aqi-analyzer/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def shout(text):
    """Return the text in uppercase with an exclamation mark."""
    return text.upper() + "!"


print(shout("hello groq"))
# Out:
# HELLO GROQ!

# %%
questions = [
    "What is a variable?",
    "What is a loop?",
    "What is a dictionary?",
]


for i, q in enumerate(questions, start=1):
    print(f"{i}. {q}")
# Out:
# 1. What is a variable?
# 2. What is a loop?
# 3. What is a dictionary?

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 1.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
import os
from groq import Groq

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API")
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

M="openai/gpt-oss-120b"
def groq_chat(prompt, model=M,temperarture=None):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperarture,
    )
    return response.choices[0].message.content

# %%
n=int(input())

for i in range(n):
  q=input()
  print(groq_chat(q))
# Out:
# 1
# how are you
# I'm doing great, thanks for asking! How can I help you today?
